# %%
#create functionality to: 

from splinter import Browser
from bs4 import BeautifulSoup
import requests
import pymongo
import pandas as pd
from selenium import webdriver

# %%
flags_url = 'http://flagpedia.net/index'
response = requests.get(flags_url)

# html = response.html
soup = BeautifulSoup(response.text, 'html.parser')

# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="//flags.fmcdn.net" rel="dns-prefetch"/>
#   <meta content="all, follow" name="robots"/>
#   <meta content="David Krmela" name="author"/>
#   <meta content="List of all countries, flags of states, and basic information including the capital, population and area." name="description"/>
#   <meta content="flags, countries, world, eu, osn, nato, game, free" name="keywords"/>
#   <title>
#    All countries | Flags of countries
#   </title>
#   <meta content="All countries | Flags of countries" property="og:title"/>
#   <meta content="Flags of all countries" property="og:description"/>
#   <meta content="http://flagpedia.net/ico-en.gif" property="og:image"/>
#   <meta content="http://flagpedia.net/index" property="og:url"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="http://flagpedia.net/index" rel="canonical"/>
# ...

# %%
soup.find('td', class_='td-country').find('a', href=True)['href']
# Out:
# '/afghanistan'

# %%
for td in soup.find_all(class_='td-country'):
    td_str = str(td)
    td_short = td_str[32:]
    print(td_short)
    link_end = td_short.find('"')
    href = td_short[:link_end]
    print(href)
# Out:
# /afghanistan">Afghanistan</a></td>
# /afghanistan
# /albania">Albania</a></td>
# /albania
# /algeria">Algeria</a></td>
# /algeria
# /andorra">Andorra</a></td>
# /andorra
# /angola">Angola</a></td>
# /angola
# /antigua-and-barbuda">Antigua and Barbuda</a></td>
# /antigua-and-barbuda
# /argentina">Argentina</a></td>
# /argentina
# /armenia">Armenia</a></td>
# /armenia
# /australia">Australia</a></td>
# /australia
# /austria">Austria</a></td>
# /austria
# /azerbaijan">Azerbaijan</a></td>
# /azerbaijan
# /the-bahamas">The Bahamas</a></td>
# /the-bahamas
# /bahrain">Bahrain</a></td>
# /bahrain
# /bangladesh">Bangladesh</a></td>
# /bangladesh
# /barbados">Barbados</a></td>
# /barbados
# /belarus">Belarus</a></td>
# /belarus
# /belgium">Belgium</a></td>
# /belgium
# /belize">Belize</a></td>
# /belize
# /benin">Benin</a></td>
# /benin
# /bhutan">Bhutan</a></td>
# /bhutan
# /bolivia">Bolivia</a></td>
# /bolivia
# /bosnia-and-herzegovina">Bosnia and Herzegovina</a></td>
# ...

# %%
for link in soup.find_all('a'):
    print('http://flagpedia.net' + link.get('href'))
# Out:
# http://flagpedia.net/afghanistan
# http://flagpedia.net/afghanistan
# http://flagpedia.net/albania
# http://flagpedia.net/albania
# http://flagpedia.net/algeria
# http://flagpedia.net/algeria
# http://flagpedia.net/andorra
# http://flagpedia.net/andorra
# http://flagpedia.net/angola
# http://flagpedia.net/angola
# http://flagpedia.net/antigua-and-barbuda
# http://flagpedia.net/antigua-and-barbuda
# http://flagpedia.net/argentina
# http://flagpedia.net/argentina
# http://flagpedia.net/armenia
# http://flagpedia.net/armenia
# http://flagpedia.net/australia
# http://flagpedia.net/australia
# http://flagpedia.net/austria
# http://flagpedia.net/austria
# http://flagpedia.net/azerbaijan
# http://flagpedia.net/azerbaijan
# http://flagpedia.net/the-bahamas
# http://flagpedia.net/the-bahamas
# http://flagpedia.net/bahrain
# http://flagpedia.net/bahrain
# http://flagpedia.net/bangladesh
# http://flagpedia.net/bangladesh
# http://flagpedia.net/barbados
# http://flagpedia.net/barbados
# ...

# %%
# Tried to do this by the table but this did not provide enough data

# country_data_url = 'https://en.wikipedia.org/wiki/List_of_national_anthems'
    
# tables = pd.read_html(country_data_url)
# tables

# %%
# url_flags_songs = 'https://en.wikipedia.org/wiki/List_of_national_anthems'
# response = requests.get(url_flags_songs)

# # html = response.html
# soup = BeautifulSoup(response.text, 'html.parser')

# # Examine the results, then determine element that contains sought info
# print(soup.prettify())

# %%
# However, Python cannot run Javascript and allow it to create the elements that hold the content that you need to scrape; the most it can do is parse the source code. In a situation like this, one in which you have to scrape content loaded dynamically by Javascript, content that is not present in the source code of the page, the Python module Selenium comes in handy.

# %%
# browser = webdriver.Chrome() 
# url = "https://en.wikipedia.org/wiki/List_of_national_anthems"
# browser.get(url) #navigate to the page

# %%
# # innerHTML = browser.execute_script("return document.body.innerHTML") #returns the inner HTML as a string
# # innerHTML

# innerHTML = browser.execute_script("return document.body.innerHTML") #returns the inner HTML as a string
# innerHTML

# %%
# #Create broswer launch 
# executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# browser = Browser('chrome', **executable_path, headless=False)

# #Splinter opens up a browser  (TEST)
# # URL of page to be scraped
# url_flags_songs = 'https://en.wikipedia.org/wiki/List_of_national_anthems'
# browser.visit(url_flags_songs)

# html = browser.html
# soup = BeautifulSoup(html, 'html.parser')

# %%
# flag_images = []

# for x in range(0,4):
    
#     flag_url = 'http://flagpedia.net/index'
#     browser.visit(flag_url)

#     html = browser.html
#     soup = BeautifulSoup(html, 'html.parser')
#     browser.find_link_by_partial_text('Hemisphere')[x].click()
    
#     html = browser.html
#     soup = BeautifulSoup(html, 'html.parser')
#     block = soup.find_all(class_='downloads')

#     for link in block:
#         link.find('a')['href']
#         hemisphere_images.append(link.find('a')['href'])
